# %%
# Import pandas library
import pandas as pd

# Define the file path (Windows)
file_path = r"C:\Users\up32n\reliance_forpowerbi_latest.csv"

# Load the CSV file into a DataFrame, parsing the Date column
df = pd.read_csv(file_path, parse_dates=["Date"])

# Display the first few rows to inspect column names and sample data
print("First 5 rows of the dataset:")
print(df.head(), "\n")

# Show a concise summary of the DataFrame, including column names, non-null counts, and dtypes
print("DataFrame info:")
df.info()
print()

# List all column names explicitly
print("Column names:")
print(df.columns.tolist(), "\n")

# Display basic descriptive statistics for numeric columns
print("Descriptive statistics:")
print(df.describe(), "\n")

# Check for missing values in each column
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# First 5 rows of the dataset:
#         Date       open       high        low      close  adj_close  \
# 0 1996-01-01  14.638248  14.716795  14.541850  14.691803   9.302441
# 1 1996-01-02  14.656100  14.727506  14.470444  14.577553   9.230103
# 2 1996-01-03  14.816763  15.491551  14.656100  14.688232   9.300181
# 3 1996-01-04  14.548991  14.595404  14.356194  14.552561   9.214280
# 4 1996-01-05  14.495436  14.495436  14.327632  14.452592   9.150982
#
#         volume       ticker  Daily_Return_adj
# 0   52060684.0  RELIANCE.NS               NaN
# 1   84371654.0  RELIANCE.NS         -0.777615
# 2  104661939.0  RELIANCE.NS          0.759232
# 3  108450132.0  RELIANCE.NS         -0.923651
# 4   83354233.0  RELIANCE.NS         -0.686958
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7124 entries, 0 to 7123
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
# ...
